# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data = pd.read_csv("mlb-umpire-scorecard.csv")
data
# Out:
#           id        date           umpire home away  home_team_runs  \
# 0          1  2022-11-05  Lance Barksdale  HOU  PHI               4
# 1          2  2022-11-03     Jordan Baker  PHI  HOU               2
# 2          3  2022-11-02     Tripp Gibson  PHI  HOU               0
# 3          4  2022-11-01     Dan Iassogna  PHI  HOU               7
# 4          5  2022-10-29       Pat Hoberg  HOU  PHI               5
# ...      ...         ...              ...  ...  ...             ...
# 18208  18209  2015-04-06      Jeff Nelson  MIA  ATL               1
# 18209  18210  2015-04-06      Ted Barrett  HOU  CLE               2
# 18210  18211  2015-04-06      Bill Miller  OAK  TEX               8
# 18211  18212  2015-04-06  Gary Cederstrom  ARI   SF               4
# 18212  18213  2015-04-05     Mike Winters  CHC  STL               0
#
#        away_team_runs pitches_called incorrect_calls expected_incorrect_calls  \
# 0                   1            124               4                       10
# 1                   3            149               6                      7.4
# 2                   5            124               7                      7.1
# 3                   0            140               5                        6
# 4                   2            129               0                      8.7
# ...               ...            ...             ...                      ...
# 18208               2            130              12                     12.7
# 18209               0            124              21                     14.2
# 18210               0            180              21                     20.9
# 18211               5            148               9                     12.2
# 18212               3            158              17                     14.7
#
#       correct_calls expected_correct_calls correct_calls_above_expected  \
# 0               120                    114                            6
# 1               143                  141.6                          1.4
# 2               117                  116.9                          0.1
# 3               135                    134                            1
# 4               129                  120.3                          8.7
# ...             ...                    ...                          ...
# 18208           118                  117.3                          0.7
# 18209           103                  109.8                         -6.8
# 18210           159                  159.1                         -0.1
# 18211           139                  135.8                          3.2
# 18212           141                  143.3                         -2.3
#
#       accuracy expected_accuracy accuracy_above_expected consistency  \
# 0         96.8                92                     4.8        97.6
# 1           96                95                     0.9        97.3
# 2         94.4              94.3                     0.1        92.7
# 3         96.4              95.7                     0.7        92.9
# 4          100              93.2                     6.8        96.1
# ...        ...               ...                     ...         ...
# 18208     90.8              90.3                     0.5        93.8
# 18209     83.1              88.5                    -5.5        91.9
# 18210     88.3              88.4                    -0.1        87.2
# 18211     93.9              91.7                     2.2        94.6
# 18212     89.2              90.7                    -1.5        94.9
#
#       favor_home total_run_impact
# 0           0.09             0.75
# 1          -0.12             0.58
# 2           -0.1             0.56
# 3           0.63             0.73
# 4              0                0
# ...          ...              ...
# 18208      -0.28             1.42
# 18209       0.51             1.97
# 18210       -0.4             2.44
# 18211      -0.36             0.84
# 18212        1.1             4.36
#
# [18213 rows x 19 columns]

# %%
data[data['favor_home']=='ND']
# Out:
#           id        date              umpire home away  home_team_runs  \
# 312      313  2022-09-16       Malachi Moore   TB  TEX               3
# 314      315  2022-09-16       David Rackley  DET  CWS               3
# 802      803  2022-08-11        John Tumpane  CIN  CHC               2
# 1528    1529  2022-06-15        Jeremy Riggs  DET  CWS               0
# 1600    1601  2022-06-10          Pat Hoberg  NYY  CHC               2
# ...      ...         ...                 ...  ...  ...             ...
# 17307  17308  2015-06-12  Hunter Wendelstedt  TEX  MIN               6
# 17473  17474  2015-05-30     Lance Barksdale  MIN  TOR               3
# 17680  17681  2015-05-15         Greg Gibson  CHC  PIT              11
# 18045  18046  2015-04-18      Bruce Dreckman  TOR  ATL               6
# 18124  18125  2015-04-12          Phil Cuzzi  MIA   TB               5
#
#        away_team_runs pitches_called incorrect_calls expected_incorrect_calls  \
# 312                 4             ND              ND                       ND
# 314                 2             ND              ND                       ND
# 802                 4             ND              ND                       ND
# 1528               13             ND              ND                       ND
# 1600                1             ND              ND                       ND
# ...               ...            ...             ...                      ...
# 17307               2             ND              ND                       ND
# 17473               2             ND              ND                       ND
# 17680              10             ND              ND                       ND
# 18045               5             ND              ND                       ND
# 18124               8             ND              ND                       ND
#
#       correct_calls expected_correct_calls correct_calls_above_expected  \
# 312              ND                     ND                           ND
# 314              ND                     ND                           ND
# 802              ND                     ND                           ND
# 1528             ND                     ND                           ND
# 1600             ND                     ND                           ND
# ...             ...                    ...                          ...
# 17307            ND                     ND                           ND
# 17473            ND                     ND                           ND
# 17680            ND                     ND                           ND
# 18045            ND                     ND                           ND
# 18124            ND                     ND                           ND
#
#       accuracy expected_accuracy accuracy_above_expected consistency  \
# 312         ND                ND                      ND          ND
# 314         ND                ND                      ND          ND
# 802         ND                ND                      ND          ND
# 1528        ND                ND                      ND          ND
# 1600        ND                ND                      ND          ND
# ...        ...               ...                     ...         ...
# 17307       ND                ND                      ND          ND
# 17473       ND                ND                      ND          ND
# 17680       ND                ND                      ND          ND
# 18045       ND                ND                      ND          ND
# 18124       ND                ND                      ND          ND
#
#       favor_home total_run_impact
# 312           ND               ND
# 314           ND               ND
# 802           ND               ND
# 1528          ND               ND
# 1600          ND               ND
# ...          ...              ...
# 17307         ND               ND
# 17473         ND               ND
# 17680         ND               ND
# 18045         ND               ND
# 18124         ND               ND
#
# [120 rows x 19 columns]

# %%
nd = data[data['favor_home']=='ND'].index
nd
# Out:
# Int64Index([  312,   314,   802,  1528,  1600,  2569,  3081,  3217,  3466,
#              4069,
#             ...
#             14644, 14921, 15098, 15761, 16301, 17307, 17473, 17680, 18045,
#             18124],
#            dtype='int64', length=120)

# %%
data = data.drop(nd, axis=0)

# %%
data
# Out:
#           id        date           umpire home away  home_team_runs  \
# 0          1  2022-11-05  Lance Barksdale  HOU  PHI               4
# 1          2  2022-11-03     Jordan Baker  PHI  HOU               2
# 2          3  2022-11-02     Tripp Gibson  PHI  HOU               0
# 3          4  2022-11-01     Dan Iassogna  PHI  HOU               7
# 4          5  2022-10-29       Pat Hoberg  HOU  PHI               5
# ...      ...         ...              ...  ...  ...             ...
# 18208  18209  2015-04-06      Jeff Nelson  MIA  ATL               1
# 18209  18210  2015-04-06      Ted Barrett  HOU  CLE               2
# 18210  18211  2015-04-06      Bill Miller  OAK  TEX               8
# 18211  18212  2015-04-06  Gary Cederstrom  ARI   SF               4
# 18212  18213  2015-04-05     Mike Winters  CHC  STL               0
#
#        away_team_runs pitches_called incorrect_calls expected_incorrect_calls  \
# 0                   1            124               4                       10
# 1                   3            149               6                      7.4
# 2                   5            124               7                      7.1
# 3                   0            140               5                        6
# 4                   2            129               0                      8.7
# ...               ...            ...             ...                      ...
# 18208               2            130              12                     12.7
# 18209               0            124              21                     14.2
# 18210               0            180              21                     20.9
# 18211               5            148               9                     12.2
# 18212               3            158              17                     14.7
#
#       correct_calls expected_correct_calls correct_calls_above_expected  \
# 0               120                    114                            6
# 1               143                  141.6                          1.4
# 2               117                  116.9                          0.1
# 3               135                    134                            1
# 4               129                  120.3                          8.7
# ...             ...                    ...                          ...
# 18208           118                  117.3                          0.7
# 18209           103                  109.8                         -6.8
# 18210           159                  159.1                         -0.1
# 18211           139                  135.8                          3.2
# 18212           141                  143.3                         -2.3
#
#       accuracy expected_accuracy accuracy_above_expected consistency  \
# 0         96.8                92                     4.8        97.6
# 1           96                95                     0.9        97.3
# 2         94.4              94.3                     0.1        92.7
# 3         96.4              95.7                     0.7        92.9
# 4          100              93.2                     6.8        96.1
# ...        ...               ...                     ...         ...
# 18208     90.8              90.3                     0.5        93.8
# 18209     83.1              88.5                    -5.5        91.9
# 18210     88.3              88.4                    -0.1        87.2
# 18211     93.9              91.7                     2.2        94.6
# 18212     89.2              90.7                    -1.5        94.9
#
#       favor_home total_run_impact
# 0           0.09             0.75
# 1          -0.12             0.58
# 2           -0.1             0.56
# 3           0.63             0.73
# 4              0                0
# ...          ...              ...
# 18208      -0.28             1.42
# 18209       0.51             1.97
# 18210       -0.4             2.44
# 18211      -0.36             0.84
# 18212        1.1             4.36
#
# [18093 rows x 19 columns]
