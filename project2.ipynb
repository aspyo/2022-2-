# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data = pd.read_csv("mlb-umpire-scorecard.csv")
data
# Out:
#           id        date           umpire home away  home_team_runs  \
# 0          1  2022-11-05  Lance Barksdale  HOU  PHI               4
# 1          2  2022-11-03     Jordan Baker  PHI  HOU               2
# 2          3  2022-11-02     Tripp Gibson  PHI  HOU               0
# 3          4  2022-11-01     Dan Iassogna  PHI  HOU               7
# 4          5  2022-10-29       Pat Hoberg  HOU  PHI               5
# ...      ...         ...              ...  ...  ...             ...
# 18208  18209  2015-04-06      Jeff Nelson  MIA  ATL               1
# 18209  18210  2015-04-06      Ted Barrett  HOU  CLE               2
# 18210  18211  2015-04-06      Bill Miller  OAK  TEX               8
# 18211  18212  2015-04-06  Gary Cederstrom  ARI   SF               4
# 18212  18213  2015-04-05     Mike Winters  CHC  STL               0
#
#        away_team_runs pitches_called incorrect_calls expected_incorrect_calls  \
# 0                   1            124               4                       10
# 1                   3            149               6                      7.4
# 2                   5            124               7                      7.1
# 3                   0            140               5                        6
# 4                   2            129               0                      8.7
# ...               ...            ...             ...                      ...
# 18208               2            130              12                     12.7
# 18209               0            124              21                     14.2
# 18210               0            180              21                     20.9
# 18211               5            148               9                     12.2
# 18212               3            158              17                     14.7
#
#       correct_calls expected_correct_calls correct_calls_above_expected  \
# 0               120                    114                            6
# 1               143                  141.6                          1.4
# 2               117                  116.9                          0.1
# 3               135                    134                            1
# 4               129                  120.3                          8.7
# ...             ...                    ...                          ...
# 18208           118                  117.3                          0.7
# 18209           103                  109.8                         -6.8
# 18210           159                  159.1                         -0.1
# 18211           139                  135.8                          3.2
# 18212           141                  143.3                         -2.3
#
#       accuracy expected_accuracy accuracy_above_expected consistency  \
# 0         96.8                92                     4.8        97.6
# 1           96                95                     0.9        97.3
# 2         94.4              94.3                     0.1        92.7
# 3         96.4              95.7                     0.7        92.9
# 4          100              93.2                     6.8        96.1
# ...        ...               ...                     ...         ...
# 18208     90.8              90.3                     0.5        93.8
# 18209     83.1              88.5                    -5.5        91.9
# 18210     88.3              88.4                    -0.1        87.2
# 18211     93.9              91.7                     2.2        94.6
# 18212     89.2              90.7                    -1.5        94.9
#
#       favor_home total_run_impact
# 0           0.09             0.75
# 1          -0.12             0.58
# 2           -0.1             0.56
# 3           0.63             0.73
# 4              0                0
# ...          ...              ...
# 18208      -0.28             1.42
# 18209       0.51             1.97
# 18210       -0.4             2.44
# 18211      -0.36             0.84
# 18212        1.1             4.36
#
# [18213 rows x 19 columns]

# %%
data[data['favor_home']=='ND']
# Out:
#           id        date              umpire home away  home_team_runs  \
# 312      313  2022-09-16       Malachi Moore   TB  TEX               3
# 314      315  2022-09-16       David Rackley  DET  CWS               3
# 802      803  2022-08-11        John Tumpane  CIN  CHC               2
# 1528    1529  2022-06-15        Jeremy Riggs  DET  CWS               0
# 1600    1601  2022-06-10          Pat Hoberg  NYY  CHC               2
# ...      ...         ...                 ...  ...  ...             ...
# 17307  17308  2015-06-12  Hunter Wendelstedt  TEX  MIN               6
# 17473  17474  2015-05-30     Lance Barksdale  MIN  TOR               3
# 17680  17681  2015-05-15         Greg Gibson  CHC  PIT              11
# 18045  18046  2015-04-18      Bruce Dreckman  TOR  ATL               6
# 18124  18125  2015-04-12          Phil Cuzzi  MIA   TB               5
#
#        away_team_runs pitches_called incorrect_calls expected_incorrect_calls  \
# 312                 4             ND              ND                       ND
# 314                 2             ND              ND                       ND
# 802                 4             ND              ND                       ND
# 1528               13             ND              ND                       ND
# 1600                1             ND              ND                       ND
# ...               ...            ...             ...                      ...
# 17307               2             ND              ND                       ND
# 17473               2             ND              ND                       ND
# 17680              10             ND              ND                       ND
# 18045               5             ND              ND                       ND
# 18124               8             ND              ND                       ND
#
#       correct_calls expected_correct_calls correct_calls_above_expected  \
# 312              ND                     ND                           ND
# 314              ND                     ND                           ND
# 802              ND                     ND                           ND
# 1528             ND                     ND                           ND
# 1600             ND                     ND                           ND
# ...             ...                    ...                          ...
# 17307            ND                     ND                           ND
# 17473            ND                     ND                           ND
# 17680            ND                     ND                           ND
# 18045            ND                     ND                           ND
# 18124            ND                     ND                           ND
#
#       accuracy expected_accuracy accuracy_above_expected consistency  \
# 312         ND                ND                      ND          ND
# 314         ND                ND                      ND          ND
# 802         ND                ND                      ND          ND
# 1528        ND                ND                      ND          ND
# 1600        ND                ND                      ND          ND
# ...        ...               ...                     ...         ...
# 17307       ND                ND                      ND          ND
# 17473       ND                ND                      ND          ND
# 17680       ND                ND                      ND          ND
# 18045       ND                ND                      ND          ND
# 18124       ND                ND                      ND          ND
#
#       favor_home total_run_impact
# 312           ND               ND
# 314           ND               ND
# 802           ND               ND
# 1528          ND               ND
# 1600          ND               ND
# ...          ...              ...
# 17307         ND               ND
# 17473         ND               ND
# 17680         ND               ND
# 18045         ND               ND
# 18124         ND               ND
#
# [120 rows x 19 columns]

# %%
nd = data[data['favor_home']=='ND'].index
nd
# Out:
# Int64Index([  312,   314,   802,  1528,  1600,  2569,  3081,  3217,  3466,
#              4069,
#             ...
#             14644, 14921, 15098, 15761, 16301, 17307, 17473, 17680, 18045,
#             18124],
#            dtype='int64', length=120)

# %%
data = data.drop(nd, axis=0)

# %%
data
# Out:
#           id        date           umpire home away  home_team_runs  \
# 0          1  2022-11-05  Lance Barksdale  HOU  PHI               4
# 1          2  2022-11-03     Jordan Baker  PHI  HOU               2
# 2          3  2022-11-02     Tripp Gibson  PHI  HOU               0
# 3          4  2022-11-01     Dan Iassogna  PHI  HOU               7
# 4          5  2022-10-29       Pat Hoberg  HOU  PHI               5
# ...      ...         ...              ...  ...  ...             ...
# 18208  18209  2015-04-06      Jeff Nelson  MIA  ATL               1
# 18209  18210  2015-04-06      Ted Barrett  HOU  CLE               2
# 18210  18211  2015-04-06      Bill Miller  OAK  TEX               8
# 18211  18212  2015-04-06  Gary Cederstrom  ARI   SF               4
# 18212  18213  2015-04-05     Mike Winters  CHC  STL               0
#
#        away_team_runs pitches_called incorrect_calls expected_incorrect_calls  \
# 0                   1            124               4                       10
# 1                   3            149               6                      7.4
# 2                   5            124               7                      7.1
# 3                   0            140               5                        6
# 4                   2            129               0                      8.7
# ...               ...            ...             ...                      ...
# 18208               2            130              12                     12.7
# 18209               0            124              21                     14.2
# 18210               0            180              21                     20.9
# 18211               5            148               9                     12.2
# 18212               3            158              17                     14.7
#
#       correct_calls expected_correct_calls correct_calls_above_expected  \
# 0               120                    114                            6
# 1               143                  141.6                          1.4
# 2               117                  116.9                          0.1
# 3               135                    134                            1
# 4               129                  120.3                          8.7
# ...             ...                    ...                          ...
# 18208           118                  117.3                          0.7
# 18209           103                  109.8                         -6.8
# 18210           159                  159.1                         -0.1
# 18211           139                  135.8                          3.2
# 18212           141                  143.3                         -2.3
#
#       accuracy expected_accuracy accuracy_above_expected consistency  \
# 0         96.8                92                     4.8        97.6
# 1           96                95                     0.9        97.3
# 2         94.4              94.3                     0.1        92.7
# 3         96.4              95.7                     0.7        92.9
# 4          100              93.2                     6.8        96.1
# ...        ...               ...                     ...         ...
# 18208     90.8              90.3                     0.5        93.8
# 18209     83.1              88.5                    -5.5        91.9
# 18210     88.3              88.4                    -0.1        87.2
# 18211     93.9              91.7                     2.2        94.6
# 18212     89.2              90.7                    -1.5        94.9
#
#       favor_home total_run_impact
# 0           0.09             0.75
# 1          -0.12             0.58
# 2           -0.1             0.56
# 3           0.63             0.73
# 4              0                0
# ...          ...              ...
# 18208      -0.28             1.42
# 18209       0.51             1.97
# 18210       -0.4             2.44
# 18211      -0.36             0.84
# 18212        1.1             4.36
#
# [18093 rows x 19 columns]

# %%
data = data.astype({'favor_home':'float'})
data.dtypes
# Out:
# id                                int64
# date                             object
# umpire                           object
# home                             object
# away                             object
# home_team_runs                    int64
# away_team_runs                    int64
# pitches_called                   object
# incorrect_calls                  object
# expected_incorrect_calls         object
# correct_calls                    object
# expected_correct_calls           object
# correct_calls_above_expected     object
# accuracy                         object
# expected_accuracy                object
# accuracy_above_expected          object
# consistency                      object
# favor_home                      float64
# total_run_impact                 object
# dtype: object

# %%
plt.plot(data['favor_home'], 'ro')
plt.xlabel('count')
plt.ylabel('favor_home')
# Out:
# Text(0, 0.5, 'favor_home')

# %%
fig, ax = plt.subplots()
box = ax.boxplot(data['favor_home'])
plt.xticks([1], ['favor_home'])
plt.show()
print(np.quantile(data['favor_home'], (0.25, 0.50, 0.75)))
print(data.describe())
# Out:
# [-0.33  0.03  0.4 ]
#                  id  home_team_runs  away_team_runs    favor_home
# count  18093.000000    18093.000000    18093.000000  18093.000000
# mean    9097.235063        4.560880        4.432046      0.034539
# std     5265.213979        3.153966        3.204674      0.637280
# min        1.000000        0.000000        0.000000     -3.450000
# 25%     4534.000000        2.000000        2.000000     -0.330000
# 50%     9085.000000        4.000000        4.000000      0.030000
# 75%    13677.000000        6.000000        6.000000      0.400000
# max    18213.000000       29.000000       28.000000      3.400000

# %%
IQR = 0.40 - (-0.33)
outlier1 = -0.33 - 1.5*IQR
outlier2 = 0.40 + 1.5*IQR
print(outlier1, outlier2)
# Out:
# -1.425 1.495

# %%
print(data[data['favor_home'] > 1.495])
# Out:
#           id        date          umpire home away  home_team_runs  \
# 164      165  2022-09-27    Ryan Blakney  NYM  MIA               4
# 273      274  2022-09-19  Mike Estabrook  COL   SF               7
# 317      318  2022-09-16   Edwin Moscoso  MIL  NYY               7
# 697      698  2022-08-18  Ramon De Jesus  CWS  HOU               5
# 803      804  2022-08-10  Bruce Dreckman  NYM  CIN              10
# ...      ...         ...             ...  ...  ...             ...
# 18052  18053  2015-04-18     Paul Nauert  HOU  LAA               4
# 18055  18056  2015-04-18    Bob Davidson   TB  NYY               0
# 18056  18057  2015-04-18   Lance Barrett   SF  ARI               4
# 18085  18086  2015-04-15     Sean Barber  BAL  NYY               7
# 18088  18089  2015-04-15   Andy Fletcher  CHC  CIN               5
#
#        away_team_runs pitches_called incorrect_calls expected_incorrect_calls  \
# 164                 6            177              15                     16.6
# 273                10            173              19                     12.5
# 317                 6            228              22                     17.3
# 697                21            200              15                     15.1
# 803                 2            161               9                      9.2
# ...               ...            ...             ...                      ...
# 18052               0            149              20                       17
# 18055               9            181              17                     16.4
# 18056               1            154              22                     15.6
# 18085               5            173              19                     16.3
# 18088               0            135              24                     15.9
#
#       correct_calls expected_correct_calls correct_calls_above_expected  \
# 164             162                  160.4                          1.6
# 273             154                  160.5                         -6.5
# 317             206                  210.7                         -4.7
# 697             185                  184.9                          0.1
# 803             152                  151.8                          0.2
# ...             ...                    ...                          ...
# 18052           129                    132                           -3
# 18055           164                  164.6                         -0.6
# 18056           132                  138.4                         -6.4
# 18085           154                  156.7                         -2.7
# 18088           111                  119.1                         -8.1
#
#       accuracy expected_accuracy accuracy_above_expected consistency  \
# 164       91.5              90.6                     0.9        89.8
# 273         89              92.8                    -3.7        90.2
# 317       90.4              92.4                      -2        91.7
# 697       92.5              92.4                     0.1        91.5
# 803       94.4              94.3                     0.1        93.8
# ...        ...               ...                     ...         ...
# 18052     86.6              88.6                      -2        89.9
# 18055     90.6              90.9                    -0.3        92.8
# 18056     85.7              89.9                    -4.2        91.6
# 18085       89              90.6                    -1.6        93.1
# 18088     82.2              88.2                      -6        92.6
#
#        favor_home total_run_impact
# 164          2.72             3.16
# 273          1.87             2.89
# 317          2.18             4.06
# 697          1.75             2.47
# 803          1.80             2.16
# ...           ...              ...
# 18052        1.60             2.16
# 18055        2.03             2.29
# 18056        2.49             3.89
# 18085        2.33             2.99
# 18088        1.86             3.38
#
# [305 rows x 19 columns]

# %%
print(data[data['favor_home'] < -1.425])
# Out:
#           id        date        umpire home away  home_team_runs  \
# 115      116  2022-10-01     Adam Beck   SD  CWS               5
# 362      363  2022-09-12    John Libka  MIA  TEX               2
# 365      366  2022-09-12   Cory Blaser  DET  HOU               0
# 443      444  2022-09-06   Jeff Nelson  BAL  TOR               9
# 564      565  2022-08-28      Laz Diaz   KC   SD              15
# ...      ...         ...           ...  ...  ...             ...
# 17975  17976  2015-04-24   Mark Wegner   SD  LAD               0
# 17979  17980  2015-04-23  Chris Conroy  PHI  MIA               1
# 18014  18015  2015-04-21   Ted Barrett  MIL  CIN              10
# 18040  18041  2015-04-19  Dan Iassogna   SF  ARI               1
# 18132  18133  2015-04-12   Mike DiMuro  OAK  SEA               7
#
#        away_team_runs pitches_called incorrect_calls expected_incorrect_calls  \
# 115                 2            144              10                     10.2
# 362                 3            134               6                      5.7
# 365                 7            128              10                      9.5
# 443                 6            164               7                      8.3
# 564                 7            200              21                       13
# ...               ...            ...             ...                      ...
# 17975               3            144              14                     14.6
# 17979               9            162              12                     15.7
# 18014              16            180              12                     19.8
# 18040               5            112              13                     12.2
# 18132               8            162              19                       13
#
#       correct_calls expected_correct_calls correct_calls_above_expected  \
# 115             134                  133.8                          0.2
# 362             128                  128.3                         -0.3
# 365             118                  118.5                         -0.5
# 443             157                  155.7                          1.3
# 564             179                    187                           -8
# ...             ...                    ...                          ...
# 17975           130                  129.4                          0.6
# 17979           150                  146.3                          3.7
# 18014           168                  160.2                          7.8
# 18040            99                   99.8                         -0.8
# 18132           143                    149                           -6
#
#       accuracy expected_accuracy accuracy_above_expected consistency  \
# 115       93.1              92.9                     0.1        91.7
# 362       95.5              95.8                    -0.3        94.8
# 365       92.2              92.6                    -0.4        91.4
# 443       95.7              94.9                     0.8        95.7
# 564       89.5              93.5                      -4        92.5
# ...        ...               ...                     ...         ...
# 17975     90.3              89.8                     0.4        88.2
# 17979     92.6              90.3                     2.3        92.6
# 18014     93.3                89                     4.3        91.1
# 18040     88.4              89.1                    -0.7        92.9
# 18132     88.3                92                    -3.7        92.6
#
#        favor_home total_run_impact
# 115         -2.37             2.87
# 362         -1.55             2.11
# 365         -1.44              1.8
# 443         -1.54             1.72
# 564         -2.50             3.94
# ...           ...              ...
# 17975       -1.43             1.97
# 17979       -2.16             2.64
# 18014       -2.14             2.54
# 18040       -1.64             2.12
# 18132       -1.45             2.35
#
# [272 rows x 19 columns]

# %%
#t-test 수행하기 전 조건 만족하는지 확인
#독립성은 만족
#Normality 체크
#1. 정규성 검사(시각화) : Histogram
plt.hist(data['favor_home'])
# Out:
# (array([   9.,   42.,  249., 1551., 6516., 7151., 2122.,  368.,   61.,
#           24.]),
#  array([-3.45 , -2.765, -2.08 , -1.395, -0.71 , -0.025,  0.66 ,  1.345,
#          2.03 ,  2.715,  3.4  ]),
#  <BarContainer object of 10 artists>)

# %%
#2. 정규성 검사(시각화) : Q-Q plot
import statsmodels.api as sm
sm.qqplot(data['favor_home'], line='45')
